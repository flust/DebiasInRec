# %%
import csv

# Field 1, 2
field0 = [ 'artist_name' , 'genre_ids']
all_fields = [field0]

feat_dict = {}
all_idx = [-1]


def add_feat(key, value, field):
    global all_idx
    global feat_dict
    real_key = "{0}:{1}".format(key, value)
    if real_key in feat_dict:
        return feat_dict[real_key]
    all_idx[field] += 1
    feat_dict[real_key] = all_idx[field]
    return all_idx[field]

def make_tuple(feat_list,field):
    feat_str = ["%d:1" % i for i in feat_list]
    fnc = lambda x: "{}:{}".format(int(field), x)
    return list(map(fnc, feat_str))

# %%
of = open('item.ffm', 'w')
rf = open('item.csv')
for line in csv.DictReader(rf, delimiter=','):
    # Key1
    output = ""
    for i, field_i in enumerate(all_fields):
        feat_idx_list = []
        for key in field_i:
            if line[key] == "":
                continue
            values = line[key].split("|")
            print(values)
            for val in values:
                feat_idx_list.append(add_feat(key, val.strip(), i))
        if len(output) != 0:
            output = "{} {}".format(output," ".join(make_tuple(feat_idx_list, i)))
        else:
            output = " ".join(make_tuple(feat_idx_list, i))

    print( output, file=of )

print(all_idx)
of.close()
# Out:
# ['A-Lin']
# ['458', '437', '465', 'nan']
# ['Adele']
# ['465']
# ['Alan Walker']
# ['1616', '1609']
# ['Ariana Grande']
# ['921', '691', '465', '1609']
# ['Avril Lavigne']
# ['465', 'nan']
# ['BANGTAN BOYS']
# ['444', '1259', '465']
# ['BIGBANG']
# ['444', '1259', '465', '2022']
# ['Bii畢書盡+陳勢安+陳彥允+李玉璽']
# ['465', 'nan']
# ['Bruno Mars']
# ['921', '465', '1609']
# ['CHARLIE PUTH']
# ['1259', '465', '1609']
# ['Calvin Harris']
# ['109', '465', '2022', '1609']
# ['Coldplay']
# ['nan', '465', '1609', '1152', '359', '2022', '921']
# ['DJ Snake']
# ['1259', '1609']
# ['David Guetta']
# ['nan', '139', '1259', '2107', '465', '1609']
# ['EXO']
# ['nan', '465', '444', '458', '437', '921']
# ['Ed Sheeran']
# ['465', '430', '1609']
# ['Eric 周興哲']
# ['458', '465']
# ['Fifth Harmony']
# ['691', '465', '1609']
# ['Flo Rida']
# ['921', '1259', '465', '1609']
# ['G.E.M.鄧紫棋']
# ['451', '109', '430', 'nan', '139', '1259', '465', '458', '1633', '1609', '1568', '359', '125', '94']
# ['Justin Bieber']
# ['691', '465']
# ['MP魔幻力量 (Magic Power)']
# ['458', '465', 'nan']
# ['Maroon 5']
# ['2189', '465', '1609', '367', '691', '2022']
# ['ONE OK ROCK']
# ['465', '2022']
# ['One Direction']
# ['465']
# ['RADWIMPS']
# ['2022', '921']
# ['Rihanna']
# ['109', '2022', 'nan', '139', '1259', '465', '1609', '125']
# ['S.H.E']
# ['458', '465']
# ['Shawn Mendes']
# ['465']
# ['Sia']
# ['465', '2122', '1609', '2022', '921']
# ['TWICE']
# ['444']
# ['Taeyeon']
# ['444', '465', '921']
# ['Taylor Swift']
# ['1011', '465', '691', 'nan']
# ['The Chainsmokers']
# ['465', '1609']
# ['The Weeknd']
# ['921', '1609', '139']
# ['Under Lover (地下情人)']
# ['1259', '465']
# ['aMEI (張惠妹)']
# ['458', '465']
# ['ジブリサウンドトラック']
# ['921', 'nan']
# ['丁噹 (Della)']
# ['451', 'nan', '465', '458', '921']
# ['五月天 (Mayday)']
# ['458', '465', '921', 'nan']
# ['伍佰 & China Blue']
# ['458', '465', '921', '1609']
# ['信 (Shin)']
# ['458', '465']
# ['兄弟本色G.U.T.S. (姚中仁、張震嶽、頑童MJ116)']
# ['458', '465']
# ['八三夭 (The Last Day of Summer 831)']
# ['451', 'nan', '465', '458', '2022']
# ['動力火車 (Power Station)']
# ['458', '465', 'nan']
# ['吳克群 (Kenji Wu)']
# ['458', '465', '921']
# ['周杰倫 (Jay Chou)']
# ['458', '1605', '465']
# ['周湯豪 (NICKTHEREAL)']
# ['458', '465']
# ['孫子涵 (Niko Sun)']
# ['458', '465', 'nan']
# ['孫燕姿 (Yanzi Sun)']
# ['458', '465']
# ['孫盛希 (Shi Shi)']
# ['458', '465', 'nan']
# ['家家 (JiaJia)']
# ['458', '465']
# ['張學友 (Jacky Cheung)']
# ['451', 'nan', '465', '2122', '458']
# ['張宇 (Phil Chang)']
# ['465', '921']
# ['張韶涵 (Angela Chang)']
# ['458', '465', 'nan']
# ['彭佳慧 (Julia Peng)']
# ['458', '465', 'nan']
# ['徐佳瑩 (Lala Hsu)']
# ['275', '465', '1572', '458', '921']
# ['戴佩妮 (Penny Tai)']
# ['458', '1152', '465', 'nan']
# ['曾沛慈 (Pets Tseng)']
# ['458', '465', 'nan']
# ['李佳薇 (Jess Lee)']
# ['458', '465', 'nan']
# ['李榮浩']
# ['465']
# ['李聖傑 (Sam Lee)']
# ['465']
# ['林俊傑 (JJ Lin)']
# ['458', '465', 'nan']
# ['林宥嘉 (Yoga Lin)']
# ['458', '465', 'nan']
# ['梁文音 (Rachel Liang)']
# ['458', '451', '465', '786']
# ['梁靜茹 (Fish Leong)']
# ['458', '465', '921']
# ['楊丞琳 (Rainie Yang)']
# ['458', '465']
# ['江蕙 (Jody Jiang)']
# ['nan', '1082', '465', '829', '1152', '2157']
# ['王力宏 (Leehom Wang)']
# ['458', '465', 'nan']
# ['王心凌 (Cyndi Wang)']
# ['458', '465']
# ['王菲 (Faye Wong)']
# ['458', '451', '465']
# ['王詩安 (Diana Wang)']
# ['458', '465']
# ['玖壹壹']
# ['458', '1259', '465']
# ['田馥甄 (Hebe)']
# ['458', '465', 'nan']
# ['畢書盡 (Bii)']
# ['444', '458', '465', 'nan']
# ['羅志祥 (Show Lo)']
# ['458', '465', 'nan']
# ['范瑋琪 (Christine Fan)']
# ['458', '465']
# ['莊心妍']
# ['458', '451', '465', '2157']
# ['莫文蔚 (Karen Mok)']
# ['921', '458', '465', 'nan']
# ['葛仲珊 (MISS KO)']
# ['1259', '458', '465']
# ['蔡依林 (Jolin Tsai)']
# ['458', '465', 'nan']
# ['蔡健雅 (Tanya Chua)']
# ['829', '451', '465', '2022']
# ['蕭亞軒 (Elva Hsiao)']
# ['458', '465']
# ['蕭敬騰 (Jam Hsiao)']
# ['465', '921', 'nan']
# ['蕭煌奇 (Ricky Hsiao)']
# ['458', '465', '873']
# ['薛之謙']
# ['458', '465', 'nan']
# ['藍又時 (Shadya Lan)']
# ['458', '465']
# ['蘇打綠 (Sodagreen)']
# ['458', '367', '465', '2189']
# ['証聲音樂圖書館 ECHO MUSIC']
# ['1011', 'nan', '2122', '786', '947', '1609', '374', '1259', '465', '437', '829', '921', '109', '1180', '444', '726', '691', '958', '125', '139', '2086', '1152', '798', '2022', '2130']
# ['謝和弦 (R-chord)']
# ['275', '2022', '465', '1572', '2157']
# ['郁可唯 (Yisa Yu)']
# ['458', '465', 'nan']
# ['郭靜 (Claire Kuo)']
# ['458', '465', 'nan']
# ['陳勢安 (Andrew Tan)']
# ['458', '465']
# ['陳嘉樺 (Ella Chen)']
# ['458', '465']
# ['陳奕迅 (Eason Chan)']
# ['458', '451', '465', '1633']
# ['陶喆 (David Tao)']
# ['465', 'nan']
# ['韋禮安 (William Wei)']
# ['458', '465', '921', 'nan']
# ['頑童MJ116']
# ['1259', '465']
# ['魏如萱 (Waa Wei)']
# ['275', 'nan', '465', '1572', '458']
# ['鼓鼓 (GBOYSWAG)']
# ['458', 'nan']
# [141]
